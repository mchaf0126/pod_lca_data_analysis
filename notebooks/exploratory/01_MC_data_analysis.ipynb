# %%
from pathlib import Path
import pandas as pd

# %%
main_directory = Path(__vsc_ipynb_file__).parents[2]
tally_path = main_directory.joinpath('data/raw/tally_commercial_includeBC.csv')
tally_test = pd.read_csv(tally_path)

# %%
tally_test = tally_test.drop(
    columns=[
        "Revit design option",
        'Revit general category',
        'Thickness of material (m)',
        'Total instance count',
        'Cumulative material area (m2)',
        'Cumulative instance volume (m3)',
        'Cumulative instance area (m2)',
        'Cumulative instance length (m)',
        'Cumulative instance perimeter (m)',
        'Tally Entry Description'
    ]
)

# %%
tally_test['Revit model'] = "Template_Model_1"

# %%
tally_test
# Out:
#           Revit model        Revit category Revit type  \
# 0    Template_Model_1  Curtainwall Mullions    Mullion
# 1    Template_Model_1  Curtainwall Mullions    Mullion
# 2    Template_Model_1  Curtainwall Mullions    Mullion
# 3    Template_Model_1  Curtainwall Mullions    Mullion
# 4    Template_Model_1  Curtainwall Mullions    Mullion
# ..                ...                   ...        ...
# 165  Template_Model_1                 Walls       Wall
# 166  Template_Model_1                 Walls       Wall
# 167  Template_Model_1                 Walls       Wall
# 168  Template_Model_1                 Walls       Wall
# 169  Template_Model_1                 Walls       Wall
#
#                  Revit family name Revit material name Revit building element  \
# 0    Rectangular Mullion: 1 Square            Aluminum              Enclosure
# 1    Rectangular Mullion: 1 Square            Aluminum              Enclosure
# ...

# %%
tally_test['element_index'] = None

# %%
for row_index, series in tally_test.iterrows():
    tally_test.loc[row_index, 'element_index'] = f'Element_{row_index // 5}'
